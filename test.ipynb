# %%
import json

with open("model/gfr_dataset.json", "r") as f:
    json_dataset = json.load(f)

# %%
import utils

dataset = utils.df_from_json(json_dataset)

# %%
import utils

model = utils.load_gfr_model(dataset, 566517779, 20, 100)

# %%
model.g.get_params()
# Out:
# {'max_current': [189.96200561523438],
#  'max_firing_rate': [0.05272439494729042],
#  'poly_coeff': [[-0.34459394216537476,
#    1.236636996269226,
#    2.4523446119672273e-16,
#    -0.051808636635541916]],
#  'b': [70.55071258544922],
#  'bin_size': 100}
